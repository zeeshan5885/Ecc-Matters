# %%
import h5py
import numpy as np
import corner

# %%
data = h5py.File('my_out_10_10_100.hdf5','r')

# %%
data.keys()
# Out:
# <KeysViewHDF5 ['init_pos', 'log_prob', 'pos']>

# %%
data_3D = np.array(data['pos'])

# %%
print('Number of samples are : ',len(data_3D))
print(data_3D)
# Out:
# Number of samples are :  100
# [[[ 1.9227031e+00 -3.6437234e-01  1.1932107e+00  9.7623650e+01
#     4.3540406e-01]
#   [ 1.0324781e+00  2.7706042e-01  9.3748417e+00  9.6748215e+01
#     9.2868078e-01]
#   [ 2.4050176e+00  4.2004919e+00  1.4847306e+00  9.8236084e+01
#     8.6776139e-03]
#   ...
#   [ 1.4578120e+00 -3.6769149e+00  7.7272096e+00  7.8467133e+01
#     9.7116733e-01]
#   [ 1.0261487e+00 -9.6415269e-01  3.1012805e+00  7.1756760e+01
#     2.7333313e-01]
#   [ 1.5637598e+00 -1.9880786e+00  1.2042534e+00  8.5972855e+01
#     8.6359590e-02]]
#
#  [[ 1.9227031e+00 -3.6437234e-01  1.1932107e+00  9.7623650e+01
#     4.3540406e-01]
#   [ 1.0324781e+00  2.7706042e-01  9.3748417e+00  9.6748215e+01
#     9.2868078e-01]
#   [ 2.4050176e+00  4.2004919e+00  1.4847306e+00  9.8236084e+01
#     8.6776139e-03]
#   ...
#   [ 1.4578120e+00 -3.6769149e+00  7.7272096e+00  7.8467133e+01
#     9.7116733e-01]
#   [ 1.3678159e+00 -7.3558295e-01  2.3741360e+00  8.1614349e+01
#     3.3509660e-01]
#   [ 1.5637598e+00 -1.9880786e+00  1.2042534e+00  8.5972855e+01
#     8.6359590e-02]]
#
#  [[ 1.9227031e+00 -3.6437234e-01  1.1932107e+00  9.7623650e+01
#     4.3540406e-01]
#   [ 1.0324781e+00  2.7706042e-01  9.3748417e+00  9.6748215e+01
#     9.2868078e-01]
#   [ 2.4050176e+00  4.2004919e+00  1.4847306e+00  9.8236084e+01
#     8.6776139e-03]
#   ...
#   [ 1.4578120e+00 -3.6769149e+00  7.7272096e+00  7.8467133e+01
#     9.7116733e-01]
#   [ 1.3678159e+00 -7.3558295e-01  2.3741360e+00  8.1614349e+01
#     3.3509660e-01]
#   [ 1.7194095e+00 -1.2839861e+00  1.1994649e+00  9.1025024e+01
#     2.3771676e-01]]
#
#  ...
#
#  [[ 2.7450552e+00  4.9515012e-01  1.4673480e+00  9.7340904e+01
#     4.1518325e-01]
#   [ 1.0324781e+00  2.7706042e-01  9.3748417e+00  9.6748215e+01
#     9.2868078e-01]
#   [ 2.9594316e+00  5.3159648e-01  3.7286808e+00  8.4126564e+01
#     5.6814283e-01]
#   ...
#   [ 2.7245395e+00  7.9436749e-01  4.5455985e+00  8.6416893e+01
#     7.1790212e-01]
#   [ 2.6346016e+00  2.3061310e-01  1.0858902e+00  9.3382889e+01
#     9.6604817e-02]
#   [ 2.5489876e+00  7.0919955e-01  3.5728004e+00  8.7538475e+01
#     3.8010862e-01]]
#
#  [[ 2.7450552e+00  4.9515012e-01  1.4673480e+00  9.7340904e+01
#     4.1518325e-01]
#   [ 1.0324781e+00  2.7706042e-01  9.3748417e+00  9.6748215e+01
#     9.2868078e-01]
#   [ 2.9594316e+00  5.3159648e-01  3.7286808e+00  8.4126564e+01
#     5.6814283e-01]
#   ...
#   [ 2.6816099e+00  8.4239244e-01  4.6949015e+00  8.6835480e+01
#     7.4527264e-01]
#   [ 2.6346016e+00  2.3061310e-01  1.0858902e+00  9.3382889e+01
#     9.6604817e-02]
#   [ 2.4620969e+00  6.9336593e-01  3.9383366e+00  8.5930122e+01
#     3.4028205e-01]]
#
#  [[ 2.7450552e+00  4.9515012e-01  1.4673480e+00  9.7340904e+01
#     4.1518325e-01]
#   [ 1.0324781e+00  2.7706042e-01  9.3748417e+00  9.6748215e+01
#     9.2868078e-01]
#   [ 2.8035481e+00  3.8715681e-01  2.4604254e+00  8.8568604e+01
#     3.4185526e-01]
#   ...
#   [ 2.6738787e+00  7.4177611e-01  4.1013451e+00  8.7912300e+01
#     6.3858938e-01]
#   [ 2.6346016e+00  2.3061310e-01  1.0858902e+00  9.3382889e+01
#     9.6604817e-02]
#   [ 2.4962268e+00 -9.2620485e-02  3.4708087e+00  7.9427719e+01
#     2.8312555e-01]]]

# %%
dat_new = data_3D.reshape((1000,5))
figure = corner.corner(dat_new,labels=[r"log rate", r"alpha", r"m_min",r"m_max",r"sigma_ecc"]
                      ,show_titles=True)

# %%
log_rate = [data_3D[i][j][0] for i in range(100) for j in range(10)]

# %%
alpha = [data_3D[i][j][1] for i in range(100) for j in range(10)]

# %%
m_min = [data_3D[i][j][2] for i in range(100) for j in range(10)]

# %%
m_max = [data_3D[i][j][3] for i in range(100) for j in range(10)]

# %%
sigma_ecc = [data_3D[i][j][4] for i in range(100) for j in range(10)]

# %%
import matplotlib.pyplot as plt
plt.hist(log_rate, bins=31)
plt.xlabel('log_rate')
# Out:
# Text(0.5, 0, 'log_rate')

# %%
plt.hist(alpha, bins=31)
plt.xlabel('alpha')
# Out:
# Text(0.5, 0, 'alpha')

# %%
plt.hist(m_min, bins=31)
plt.xlabel('m_min')
# Out:
# Text(0.5, 0, 'm_min')

# %%
plt.hist(m_max, bins=31)
plt.xlabel('m_max')
# Out:
# Text(0.5, 0, 'm_max')

# %%
plt.hist(sigma_ecc, bins=31)
plt.xlabel('sigma_ecc')
# Out:
# Text(0.5, 0, 'sigma_ecc')
